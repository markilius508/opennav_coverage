 164:(-122.4546234298, 38.1614741674), 165:(-122.4546246690, 38.1614743089), 166:(-122.4546257922, 38.1614747455), 167:(-122.4546266891, 38.1614754351), 168:(-122.4546272716, 38.1614763100), 169:(-122.4546274827, 38.1614772843), 170:(-122.4546273014, 38.1614782623), 171:(-122.4546267457, 38.1614791480), 172:(-122.4546258701, 38.1614798545), 173:(-122.4546247605, 38.1614803123), 174:(-122.4546235260, 38.1614804765), 175:(-122.4546223833, 38.1614804717), 176:(-122.4546212405, 38.1614804663), 177:(-122.4546200978, 38.1614804609), 178:(-122.4546189550, 38.1614804555), 179:(-122.4546178123, 38.1614804502), 180:(-122.4546166695, 38.1614804448)]"

START_WAYPOINT = 0
END_WAYPOINT = 433

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np
import re

# Parse the string to extract coordinates
matches = re.findall(r'\(([^,]+),\s*([^)]+)\)', s)[START_WAYPOINT:END_WAYPOINT]
geo_poses = [
    {"lat": float(lat), "lon": float(lon), "quat": (0.0, 0.0, 0.0, 1.0)}
    for lon, lat in matches
]

def quaternion_to_yaw(x, y, z, w):
    """Convert quaternion to yaw angle in radians."""
    siny_cosp = 2.0 * (w * z + x * y)
    cosy_cosp = 1.0 - 2.0 * (y * y + z * z)
    return np.arctan2(siny_cosp, cosy_cosp)

# Extract data
latitudes = [pose["lat"] for pose in geo_poses]
longitudes = [pose["lon"] for pose in geo_poses]
yaws = [quaternion_to_yaw(*pose["quat"]) for pose in geo_poses]

# Create plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
ax.stock_img()
ax.gridlines(draw_labels=True)

# Plot waypoints with different markers
if len(geo_poses) >= 1:
    # First waypoint (square)
    ax.scatter(
        longitudes[0], latitudes[0],
        color='blue', s=50, marker='s',
        transform=ccrs.PlateCarree(),
        label='Start Waypoint'
    )
if len(geo_poses) >= 2:
    # Intermediate waypoints (circles), if any
    ax.scatter(
        longitudes[1:-1], latitudes[1:-1],
        color='red', s=50, marker='o',
        transform=ccrs.PlateCarree(),
        label='Intermediate Waypoints'
    )
if len(geo_poses) >= 1:
    # Last waypoint (triangle)
    ax.scatter(
        longitudes[-1], latitudes[-1],
        color='black', s=50, marker='^',
        transform=ccrs.PlateCarree(),
        label='End Waypoint'
    )

# Plot orientation arrows (commented out)
# arrow_length = 0.00001  # Adjust based on coordinate scale
# for lat, lon, yaw in zip(latitudes, longitudes, yaws):
#     dx = arrow_length * np.cos(yaw)
#     dy = arrow_length * np.sin(yaw)
#     ax.arrow(lon, lat, dx, dy, color='blue', width=0.000002, head_width=0.000005, transform=ccrs.PlateCarree())

# Set extent
lon_min, lon_max = min(longitudes), max(longitudes)
lat_min, lat_max = min(latitudes), max(latitudes)
lon_pad = (lon_max - lon_min) * 0.1 or 0.001
lat_pad = (lat_max - lat_min) * 0.1 or 0.001
ax.set_extent([lon_min - lon_pad, lon_max + lon_pad, lat_min - lat_pad, lat_max + lat_pad], crs=ccrs.PlateCarree())

ax.legend()
plt.show()
# Out:
# /home/markilius/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
import re
import subprocess

# Extract coordinate pairs using regex, limited to MAX_WAYPOINTS
matches = re.findall(r'\(([^,]+),\s*([^)]+)\)', s)[START_WAYPOINT:END_WAYPOINT]

waypoints = []
for lon, lat in matches:
    # Strip whitespace
    lon = lon.strip()
    lat = lat.strip()
    
    # Format each waypoint as GeoPose for the ros2 action command

    # waypoint = (
    #     f"{{position: {{latitude: {lat}, longitude: {lon}, altitude: 0.0}}, "
    #     f"orientation: {{x: 0.0, y: 0.0, z: 0.0, w: 1.0}}}}"
    # )

    waypoint = (
        "{position: {latitude: " + lat + ", longitude: "  + lon + ", altitude: 0.0}, "
        "orientation: {x: 0.0, y: 0.0, z: 0.0, w: 1.0}}"
    )
    waypoints.append(waypoint)

# Join waypoints with proper formatting
poses_str = ",\n  ".join(waypoints)

# Build the final ros2 action send_goal command
command = (
    f"ros2 action send_goal /navigate_through_gps_poses nav2_msgs/action/NavigateThroughGPSPoses "
    f"\"{{gps_poses: [\n  {poses_str}\n]}}\""
)

# Print the command for debugging
print("Executing command:")
print(command)

# Execute the command and capture output
try:
    result = subprocess.run(command, shell=True, capture_output=True, text=True)
    
    # Print output for debugging
    print("stdout:", result.stdout)
    print("stderr:", result.stderr)
    
    # Check result
    if result.returncode == 0:
        print("Command executed successfully.")
    else:
        print(f"Command failed with return code: {result.returncode}")
except Exception as e:
    print(f"Error executing command: {e}")
# Out:
# Executing command:
# ros2 action send_goal /navigate_through_gps_poses nav2_msgs/action/NavigateThroughGPSPoses "{gps_poses: [
#   {position: {latitude: 38.1614155834, longitude: -122.4546229271, altitude: 0.0}, orientation: {x: 0.0, y: 0.0, z: 0.0, w: 1.0}},
#   {position: {latitude: 38.1614155643, longitude: -122.4546187996, altitude: 0.0}, orientation: {x: 0.0, y: 0.0, z: 0.0, w: 1.0}},
#   {position: {latitude: 38.1614154036, longitude: -122.4546175643, altitude: 0.0}, orientation: {x: 0.0, y: 0.0, z: 0.0, w: 1.0}},
#   {position: {latitude: 38.1614149045, longitude: -122.4546164841, altitude: 0.0}, orientation: {x: 0.0, y: 0.0, z: 0.0, w: 1.0}},
#   {position: {latitude: 38.1614141449, longitude: -122.4546156786, altitude: 0.0}, orientation: {x: 0.0, y: 0.0, z: 0.0, w: 1.0}},
#   {position: {latitude: 38.1614134907, longitude: -122.4546147404, altitude: 0.0}, orientation: {x: 0.0, y: 0.0, z: 0.0, w: 1.0}},
# ...

# %%
import re
import subprocess

# Extract coordinate pairs using regex, limited to MAX_WAYPOINTS
matches = re.findall(r'\(([^,]+),\s*([^)]+)\)', s)[START_WAYPOINT:END_WAYPOINT]

waypoints = []
for lon, lat in matches:
    # Strip whitespace
    lon = lon.strip()
    lat = lat.strip()
    
    # Format each waypoint as GeoPose for the ros2 action command

    # waypoint = (
    #     f"{{position: {{latitude: {lat}, longitude: {lon}, altitude: 0.0}}, "
    #     f"orientation: {{x: 0.0, y: 0.0, z: 0.0, w: 1.0}}}}"
    # )

    waypoint = (
        "{position: {latitude: " + lat + ", longitude: "  + lon + ", altitude: 0.0}, "
        "orientation: {x: 0.0, y: 0.0, z: 0.0, w: 1.0}}"
    )
    waypoints.append(waypoint)

# Join waypoints with proper formatting
poses_str = ",\n  ".join(waypoints)

# Build the final ros2 action send_goal command
command = (
    f"ros2 action send_goal /follow_gps_waypoints nav2_msgs/action/FollowGPSWaypoints "
    f"\"{{gps_poses: [\n  {poses_str}\n]}}\""
)

# Print the command for debugging
print("Executing command:")
print(command)

# Execute the command and capture output
try:
    result = subprocess.run(command, shell=True, capture_output=True, text=True)
    
    # Print output for debugging
    print("stdout:", result.stdout)
    print("stderr:", result.stderr)
    
    # Check result
    if result.returncode == 0:
        print("Command executed successfully.")
    else:
        print(f"Command failed with return code: {result.returncode}")
except Exception as e:
    print(f"Error executing command: {e}")
