.26303, 2.96989), 299:(-4.35663, 3.0273), 300:(-4.4233, 3.11454), 301:(-4.45411, 3.21993), 302:(-4.44493, 3.32935), 303:(-4.397, 3.42814), 304:(-4.31673, 3.50307), 305:(-4.21488, 3.54409), 306:(-4.10509, 3.54571), 307:(-4.00207, 3.50773), 308:(-3.92137, 3.44821), 309:(-3.81983, 3.40641), 310:(-3.75, 3.4), 311:(-3.57143, 3.4), 312:(-3.39286, 3.4), 313:(-3.21429, 3.4), 314:(-3.03571, 3.4), 315:(-2.85714, 3.4), 316:(-2.67857, 3.4), 317:(-2.5, 3.4), 318:(-2.32143, 3.4), 319:(-2.14286, 3.4), 320:(-1.96429, 3.4), 321:(-1.78571, 3.4), 322:(-1.60714, 3.4), 323:(-1.42857, 3.4), 324:(-1.25, 3.4), 325:(-1.14154, 3.38276), 326:(-1.04645, 3.32783), 327:(-0.952866, 3.2703), 328:(-0.844957, 3.25), 329:(-0.73697, 3.26989), 330:(-0.643373, 3.3273), 331:(-0.576703, 3.41454), 332:(-0.545892, 3.51993), 333:(-0.555066, 3.62935), 334:(-0.602998, 3.72814), 335:(-0.683266, 3.80307), 336:(-0.785118, 3.84409), 337:(-0.894908, 3.84571), 338:(-0.99793, 3.80773), 339:(-1.07863, 3.74821), 340:(-1.18017, 3.70641), 341:(-1.25, 3.7)]"
# s = "[0:(-4.7, -1.5), 1:(-4.78812, -1.55001), 2:(-4.83008, -1.5772), 3:(-4.8687, -1.60895), 4:(-4.90757, -1.64041), 5:(-4.94617, -1.67219), 6:(-4.98464, -1.70413), 7:(-5.02314, -1.73603), 8:(-5.06157, -1.76801), 9:(-5.1, -1.8), 10:(-5.2, -1.9), 11:(-5.21734, -1.92519), 12:(-5.2, -1.9), 13:(-5.16481, -1.84939), 14:(-5.13045, -1.81306), 15:(-5.09585, -1.77697), 16:(-5.06133, -1.7408), 17:(-5.02689, -1.70455), 18:(-4.9923, -1.66844), 19:(-4.95778, -1.63228), 20:(-4.92418, -1.59525), 21:(-4.88965, -1.55908), 22:(-4.85518, -1.52287), 23:(-4.82134, -1.48606), 24:(-4.78686, -1.44985), 25:(-4.75242, -1.4136)]"
START_WAYPOINT = 0
END_WAYPOINT = 350

# %%
import re
import matplotlib.pyplot as plt

matches = re.findall(r'\(([^)]+)\)', s)[START_WAYPOINT:END_WAYPOINT]
# matches = re.findall(r'\(([^,]+),\s*([^)]+)\)', s)[START_WAYPOINT:END_WAYPOINT]
points = [tuple(map(float, match.split(','))) for match in matches]

# Separate the coordinates
xs = [p[0] for p in points]
ys = [p[1] for p in points]

# Plotting the path
plt.figure(figsize=(10, 6))
plt.plot(xs, ys, marker='o')
plt.title("Path Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()
# Out:
# /home/markilius/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
import re
import subprocess

# Extract coordinate pairs using regex, limited to MAX_WAYPOINTS
matches = re.findall(r'\(([^,]+),\s*([^)]+)\)', s)[START_WAYPOINT:END_WAYPOINT]

waypoints = []
for x, y in matches:
    # Split and strip x and y values
    x = x.strip()
    y = y.strip()
    
    # Format each waypoint as required for the ros2 action command

    # waypoint = (
    #     f"{{header: {{frame_id: 'map'}}, "
    #     f"pose: {{position: {{x: {x}, y: {y}, z: 0.0}}, "
    #     f"orientation: {{x: 0.0, y: 0.0, z: 0.0, w: 1.0}}}}}}"
    # )

    waypoint = (
        "{header: {frame_id: 'map'}, "
        "pose: {position: {x: " + x + ", y: " + y + ", z: 0.0}, "
        "orientation: {x: 0.0, y: 0.0, z: 0.0, w: 1.0}}}"
    )
    waypoints.append(waypoint)

# Join waypoints with proper formatting
poses_str = ",\n  ".join(waypoints)

# Build the final ros2 action send_goal command
command = (
    f"ros2 action send_goal /navigate_through_poses nav2_msgs/action/NavigateThroughPoses "
    f"\"{{poses: [\n  {poses_str}\n]}}\""
)

# Print the command for debugging
print("Executing command:")
print(command)

# Execute the command and capture output
try:
    result = subprocess.run(command, shell=True, capture_output=True, text=True)
    
    # Print output for debugging
    print("stdout:", result.stdout)
    print("stderr:", result.stderr)
    
    # Check result
    if result.returncode == 0:
        print("Command executed successfully.")
    else:
        print(f"Command failed with return code: {result.returncode}")
except Exception as e:
    print(f"Error executing command: {e}")
# Out:
# Executing command:
# ros2 action send_goal /navigate_through_poses nav2_msgs/action/NavigateThroughPoses "{poses: [
#   {header: {frame_id: 'map'}, pose: {position: {x: -3.75, y: 0.4, z: 0.0}, orientation: {x: 0.0, y: 0.0, z: 0.0, w: 1.0}}},
#   {header: {frame_id: 'map'}, pose: {position: {x: -3.57143, y: 0.4, z: 0.0}, orientation: {x: 0.0, y: 0.0, z: 0.0, w: 1.0}}},
#   {header: {frame_id: 'map'}, pose: {position: {x: -3.39286, y: 0.4, z: 0.0}, orientation: {x: 0.0, y: 0.0, z: 0.0, w: 1.0}}},
#   {header: {frame_id: 'map'}, pose: {position: {x: -3.21429, y: 0.4, z: 0.0}, orientation: {x: 0.0, y: 0.0, z: 0.0, w: 1.0}}},
#   {header: {frame_id: 'map'}, pose: {position: {x: -3.03571, y: 0.4, z: 0.0}, orientation: {x: 0.0, y: 0.0, z: 0.0, w: 1.0}}},
#   {header: {frame_id: 'map'}, pose: {position: {x: -2.85714, y: 0.4, z: 0.0}, orientation: {x: 0.0, y: 0.0, z: 0.0, w: 1.0}}},
# ...

# %%
import re
import subprocess

# Extract coordinate pairs using regex, limited to MAX_WAYPOINTS
matches = re.findall(r'\(([^,]+),\s*([^)]+)\)', s)[START_WAYPOINT:END_WAYPOINT]

waypoints = []
for x, y in matches:
    # Split and strip x and y values
    x = x.strip()
    y = y.strip()
    
    # Format each waypoint as required for the ros2 action command

    # waypoint = (
    #     f"{{header: {{frame_id: 'map'}}, "
    #     f"pose: {{position: {{x: {x}, y: {y}, z: 0.0}}, "
    #     f"orientation: {{x: 0.0, y: 0.0, z: 0.0, w: 1.0}}}}}}"
    # )

    waypoint = (
        "{header: {frame_id: 'map'}, "
        "pose: {position: {x: " + x + ", y: " + y + ", z: 0.0}, "
        "orientation: {x: 0.0, y: 0.0, z: 0.0, w: 1.0}}}"
    )
    waypoints.append(waypoint)

# Join waypoints with proper formatting
poses_str = ",\n  ".join(waypoints)

# Build the final ros2 action send_goal command
command = (
    f"ros2 action send_goal /follow_waypoints nav2_msgs/action/FollowWaypoints "
    f"\"{{poses: [\n  {poses_str}\n]}}\""
)

# Print the command for debugging
print("Executing command:")
print(command)

# Execute the command and capture output
try:
    result = subprocess.run(command, shell=True, capture_output=True, text=True)
    
    # Print output for debugging
    print("stdout:", result.stdout)
    print("stderr:", result.stderr)
    
    # Check result
    if result.returncode == 0:
        print("Command executed successfully.")
    else:
        print(f"Command failed with return code: {result.returncode}")
except Exception as e:
    print(f"Error executing command: {e}")
# Out:
# Executing command:
# ros2 action send_goal /follow_waypoints nav2_msgs/action/FollowWaypoints "{poses: [
#   {header: {frame_id: 'map'}, pose: {position: {x: -3.75, y: 0.4, z: 0.0}}},
#   {header: {frame_id: 'map'}, pose: {position: {x: -3.57143, y: 0.4, z: 0.0}}},
#   {header: {frame_id: 'map'}, pose: {position: {x: -3.39286, y: 0.4, z: 0.0}}},
#   {header: {frame_id: 'map'}, pose: {position: {x: -3.21429, y: 0.4, z: 0.0}}},
#   {header: {frame_id: 'map'}, pose: {position: {x: -3.03571, y: 0.4, z: 0.0}}},
#   {header: {frame_id: 'map'}, pose: {position: {x: -2.85714, y: 0.4, z: 0.0}}},
#   {header: {frame_id: 'map'}, pose: {position: {x: -2.67857, y: 0.4, z: 0.0}}},
#   {header: {frame_id: 'map'}, pose: {position: {x: -2.5, y: 0.4, z: 0.0}}},
#   {header: {frame_id: 'map'}, pose: {position: {x: -2.32143, y: 0.4, z: 0.0}}},
#   {header: {frame_id: 'map'}, pose: {position: {x: -2.14286, y: 0.4, z: 0.0}}},
# ...
